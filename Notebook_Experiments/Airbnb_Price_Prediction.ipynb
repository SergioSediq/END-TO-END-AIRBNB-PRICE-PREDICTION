# %% [markdown]
# # Importing Libraries

# %%
pip install catboost

# %%
Requirement already satisfied: numpy in c:\users\sergio\appdata\roaming\python\python312\site-packages (from -r requirements.txt (line 1)) (1.26.2)
Requirement already satisfied: pandas in c:\users\sergio\appdata\roaming\python\python312\site-packages (from -r requirements.txt (line 2)) (2.1.4)
Requirement already satisfied: scikit-learn in c:\users\sergio\appdata\roaming\python\python312\site-packages (from -r requirements.txt (line 3)) (1.3.2)
Requirement already satisfied: flask in c:\users\sergio\appdata\roaming\python\python312\site-packages (from -r requirements.txt (line 4)) (3.1.0)
Requirement already satisfied: pillow in c:\users\sergio\appdata\roaming\python\python312\site-packages (from -r requirements.txt (line 5)) (10.4.0)
Requirement already satisfied: catboost in c:\users\sergio\appdata\roaming\python\python312\site-packages (from -r requirements.txt (line 6)) (1.2.8)
Requirement already satisfied: dvc in c:\users\sergio\appdata\roaming\python\python312\site-packages (from -r requirements.txt (line 7)) (3.65.0)
Requirement already satisfied: xgboost in c:\users\sergio\appdata\roaming\python\python312\site-packages (from -r requirements.txt (line 9)) (2.0.3)
Requirement already satisfied: seaborn in c:\users\sergio\appdata\roaming\python\python312\site-packages (from -r requirements.txt (line 10)) (0.13.0)
Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
Requirement already satisfied: pytz>=2020.1 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from pandas->-r requirements.txt (line 2)) (2024.2)
Requirement already satisfied: tzdata>=2022.1 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from pandas->-r requirements.txt (line 2)) (2025.3)
Requirement already satisfied: scipy>=1.5.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from scikit-learn->-r requirements.txt (line 3)) (1.11.4)
Requirement already satisfied: joblib>=1.1.1 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from scikit-learn->-r requirements.txt (line 3)) (1.3.2)
Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from scikit-learn->-r requirements.txt (line 3)) (3.5.0)
Requirement already satisfied: Werkzeug>=3.1 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from flask->-r requirements.txt (line 4)) (3.1.3)
Requirement already satisfied: Jinja2>=3.1.2 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from flask->-r requirements.txt (line 4)) (3.1.5)
Requirement already satisfied: itsdangerous>=2.2 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from flask->-r requirements.txt (line 4)) (2.2.0)
Requirement already satisfied: click>=8.1.3 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from flask->-r requirements.txt (line 4)) (8.1.8)
Requirement already satisfied: blinker>=1.9 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from flask->-r requirements.txt (line 4)) (1.9.0)
Requirement already satisfied: graphviz in c:\users\sergio\appdata\roaming\python\python312\site-packages (from catboost->-r requirements.txt (line 6)) (0.21)
Requirement already satisfied: matplotlib in c:\users\sergio\appdata\roaming\python\python312\site-packages (from catboost->-r requirements.txt (line 6)) (3.8.2)
Requirement already satisfied: plotly in c:\users\sergio\appdata\roaming\python\python312\site-packages (from catboost->-r requirements.txt (line 6)) (5.18.0)
Requirement already satisfied: six in c:\users\sergio\appdata\roaming\python\python312\site-packages (from catboost->-r requirements.txt (line 6)) (1.17.0)
Requirement already satisfied: attrs>=22.2.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (25.3.0)
Requirement already satisfied: celery in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (5.6.0)
Requirement already satisfied: colorama>=0.3.9 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (0.4.6)
Requirement already satisfied: configobj>=5.0.9 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (5.0.9)
Requirement already satisfied: distro>=1.3 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (1.9.0)
Requirement already satisfied: dpath<3,>=2.1.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (2.2.0)
Requirement already satisfied: dulwich in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (0.25.0)
Requirement already satisfied: dvc-data<3.18,>=3.17.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (3.17.0)
Requirement already satisfied: dvc-http>=2.29.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (2.32.0)
Requirement already satisfied: dvc-objects in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (5.2.0)
Requirement already satisfied: dvc-render<2,>=1.0.1 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (1.0.2)
Requirement already satisfied: dvc-studio-client<1,>=0.21 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (0.22.0)
Requirement already satisfied: dvc-task<1,>=0.3.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (0.40.2)
Requirement already satisfied: flatten_dict<1,>=0.4.1 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (0.4.2)
Requirement already satisfied: flufl.lock<9,>=8.1.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (8.2.0)
Requirement already satisfied: fsspec>=2024.2.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (2025.3.2)
Requirement already satisfied: funcy>=1.14 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (2.0)
Requirement already satisfied: grandalf<1,>=0.7 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (0.8)
Requirement already satisfied: gto<2,>=1.6.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (1.9.0)
Requirement already satisfied: hydra-core>=1.1 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (1.3.2)
Requirement already satisfied: iterative-telemetry>=0.0.7 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (0.0.10)
Requirement already satisfied: kombu in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (5.6.1)
Requirement already satisfied: networkx>=2.5 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (3.4.2)
Requirement already satisfied: omegaconf in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (2.3.0)
Requirement already satisfied: packaging>=19 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (23.2)
Requirement already satisfied: pathspec>=0.10.3 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (0.12.1)
Requirement already satisfied: platformdirs<5,>=3.1.1 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (4.3.8)
Requirement already satisfied: psutil>=5.8 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (7.0.0)
Requirement already satisfied: pydot>=1.2.4 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (4.0.1)
Requirement already satisfied: pygtrie>=2.3.2 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (2.5.0)
Requirement already satisfied: pyparsing>=2.4.7 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (3.2.3)
Requirement already satisfied: requests>=2.22 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (2.32.5)
Requirement already satisfied: rich>=12 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (13.9.4)
Requirement already satisfied: ruamel.yaml>=0.17.11 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (0.18.17)
Requirement already satisfied: scmrepo<4,>=3.5.2 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (3.6.0)
Requirement already satisfied: shortuuid>=0.5 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (1.0.13)
Requirement already satisfied: shtab<2,>=1.3.4 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (1.8.0)
Requirement already satisfied: tabulate>=0.8.7 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (0.9.0)
Requirement already satisfied: tomlkit>=0.11.1 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (0.13.3)
Requirement already satisfied: tqdm<5,>=4.63.1 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (4.66.1)
Requirement already satisfied: voluptuous>=0.11.7 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (0.16.0)
Requirement already satisfied: zc.lockfile>=1.2.1 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc->-r requirements.txt (line 7)) (4.0)
Requirement already satisfied: dictdiffer>=0.8.1 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc-data<3.18,>=3.17.0->dvc->-r requirements.txt (line 7)) (0.9.0)
Requirement already satisfied: diskcache>=5.2.1 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc-data<3.18,>=3.17.0->dvc->-r requirements.txt (line 7)) (5.6.3)
Requirement already satisfied: sqltrie<1,>=0.11.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc-data<3.18,>=3.17.0->dvc->-r requirements.txt (line 7)) (0.11.2)
Requirement already satisfied: orjson<4,>=3 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc-data<3.18,>=3.17.0->dvc->-r requirements.txt (line 7)) (3.11.5)
Requirement already satisfied: pywin32>=225 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dvc-task<1,>=0.3.0->dvc->-r requirements.txt (line 7)) (311)
Requirement already satisfied: billiard<5.0,>=4.2.1 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from celery->dvc->-r requirements.txt (line 7)) (4.2.4)
Requirement already satisfied: vine<6.0,>=5.1.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from celery->dvc->-r requirements.txt (line 7)) (5.1.0)
Requirement already satisfied: click-didyoumean>=0.3.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from celery->dvc->-r requirements.txt (line 7)) (0.3.1)
Requirement already satisfied: click-repl>=0.2.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from celery->dvc->-r requirements.txt (line 7)) (0.3.0)
Requirement already satisfied: click-plugins>=1.1.1 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from celery->dvc->-r requirements.txt (line 7)) (1.1.1.2)
Requirement already satisfied: exceptiongroup>=1.3.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from celery->dvc->-r requirements.txt (line 7)) (1.3.1)
Requirement already satisfied: tzlocal in c:\users\sergio\appdata\roaming\python\python312\site-packages (from celery->dvc->-r requirements.txt (line 7)) (5.3.1)
Requirement already satisfied: atpublic in c:\users\sergio\appdata\roaming\python\python312\site-packages (from flufl.lock<9,>=8.1.0->dvc->-r requirements.txt (line 7)) (7.0.0)
Requirement already satisfied: entrypoints in c:\users\sergio\appdata\roaming\python\python312\site-packages (from gto<2,>=1.6.0->dvc->-r requirements.txt (line 7)) (0.4)
Requirement already satisfied: pydantic>=2 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from gto<2,>=1.6.0->dvc->-r requirements.txt (line 7)) (2.12.5)
Requirement already satisfied: pydantic-settings>=2 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from gto<2,>=1.6.0->dvc->-r requirements.txt (line 7)) (2.12.0)
Requirement already satisfied: semver>=2.13.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from gto<2,>=1.6.0->dvc->-r requirements.txt (line 7)) (3.0.4)
Requirement already satisfied: typer>=0.4.1 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from gto<2,>=1.6.0->dvc->-r requirements.txt (line 7)) (0.20.1)
Requirement already satisfied: amqp<6.0.0,>=5.1.1 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from kombu->dvc->-r requirements.txt (line 7)) (5.3.1)
Requirement already satisfied: gitpython>3 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from scmrepo<4,>=3.5.2->dvc->-r requirements.txt (line 7)) (3.1.44)
Requirement already satisfied: pygit2>=1.14.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from scmrepo<4,>=3.5.2->dvc->-r requirements.txt (line 7)) (1.19.0)
Requirement already satisfied: asyncssh<3,>=2.13.1 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from scmrepo<4,>=3.5.2->dvc->-r requirements.txt (line 7)) (2.22.0)
Requirement already satisfied: aiohttp-retry>=2.5.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from scmrepo<4,>=3.5.2->dvc->-r requirements.txt (line 7)) (2.9.1)
Requirement already satisfied: cryptography>=39.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from asyncssh<3,>=2.13.1->scmrepo<4,>=3.5.2->dvc->-r requirements.txt (line 7)) (44.0.0)
Requirement already satisfied: typing_extensions>=4.0.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from asyncssh<3,>=2.13.1->scmrepo<4,>=3.5.2->dvc->-r requirements.txt (line 7)) (4.15.0)
Requirement already satisfied: aiohttp in c:\users\sergio\appdata\roaming\python\python312\site-packages (from aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc->-r requirements.txt (line 7)) (3.11.18)
Requirement already satisfied: prompt-toolkit>=3.0.36 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from click-repl>=0.2.0->celery->dvc->-r requirements.txt (line 7)) (3.0.52)
Requirement already satisfied: cffi>=1.12 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from cryptography>=39.0->asyncssh<3,>=2.13.1->scmrepo<4,>=3.5.2->dvc->-r requirements.txt (line 7)) (2.0.0)
Requirement already satisfied: pycparser in c:\users\sergio\appdata\roaming\python\python312\site-packages (from cffi>=1.12->cryptography>=39.0->asyncssh<3,>=2.13.1->scmrepo<4,>=3.5.2->dvc->-r requirements.txt (line 7)) (2.22)
Requirement already satisfied: urllib3>=2.2.2 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from dulwich->dvc->-r requirements.txt (line 7)) (2.3.0)
Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from gitpython>3->scmrepo<4,>=3.5.2->dvc->-r requirements.txt (line 7)) (4.0.12)
Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from gitdb<5,>=4.0.1->gitpython>3->scmrepo<4,>=3.5.2->dvc->-r requirements.txt (line 7)) (5.0.2)
Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\sergio\appdata\roaming\python\python312\site-packages (from hydra-core>=1.1->dvc->-r requirements.txt (line 7)) (4.9.3)
Requirement already satisfied: PyYAML>=5.1.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from omegaconf->dvc->-r requirements.txt (line 7)) (6.0.1)
Requirement already satisfied: appdirs in c:\users\sergio\appdata\roaming\python\python312\site-packages (from iterative-telemetry>=0.0.7->dvc->-r requirements.txt (line 7)) (1.4.4)
Requirement already satisfied: filelock in c:\users\sergio\appdata\roaming\python\python312\site-packages (from iterative-telemetry>=0.0.7->dvc->-r requirements.txt (line 7)) (3.18.0)
Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from Jinja2>=3.1.2->flask->-r requirements.txt (line 4)) (3.0.2)
Requirement already satisfied: contourpy>=1.0.1 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from matplotlib->catboost->-r requirements.txt (line 6)) (1.3.2)
Requirement already satisfied: cycler>=0.10 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from matplotlib->catboost->-r requirements.txt (line 6)) (0.12.1)
Requirement already satisfied: fonttools>=4.22.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from matplotlib->catboost->-r requirements.txt (line 6)) (4.58.5)
Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from matplotlib->catboost->-r requirements.txt (line 6)) (1.4.8)
Requirement already satisfied: wcwidth in c:\users\sergio\appdata\roaming\python\python312\site-packages (from prompt-toolkit>=3.0.36->click-repl>=0.2.0->celery->dvc->-r requirements.txt (line 7)) (0.2.14)
Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from pydantic>=2->gto<2,>=1.6.0->dvc->-r requirements.txt (line 7)) (0.7.0)
Requirement already satisfied: pydantic-core==2.41.5 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from pydantic>=2->gto<2,>=1.6.0->dvc->-r requirements.txt (line 7)) (2.41.5)
Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from pydantic>=2->gto<2,>=1.6.0->dvc->-r requirements.txt (line 7)) (0.4.2)
Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from pydantic-settings>=2->gto<2,>=1.6.0->dvc->-r requirements.txt (line 7)) (1.0.0)
Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from requests>=2.22->dvc->-r requirements.txt (line 7)) (3.4.1)
Requirement already satisfied: idna<4,>=2.5 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from requests>=2.22->dvc->-r requirements.txt (line 7)) (3.10)
Requirement already satisfied: certifi>=2017.4.17 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from requests>=2.22->dvc->-r requirements.txt (line 7)) (2024.12.14)
Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from rich>=12->dvc->-r requirements.txt (line 7)) (3.0.0)
Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from rich>=12->dvc->-r requirements.txt (line 7)) (2.19.1)
Requirement already satisfied: mdurl~=0.1 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from markdown-it-py>=2.2.0->rich>=12->dvc->-r requirements.txt (line 7)) (0.1.2)
Requirement already satisfied: ruamel.yaml.clib>=0.2.15 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from ruamel.yaml>=0.17.11->dvc->-r requirements.txt (line 7)) (0.2.15)
Requirement already satisfied: shellingham>=1.3.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from typer>=0.4.1->gto<2,>=1.6.0->dvc->-r requirements.txt (line 7)) (1.5.4)
Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from rich>=12->dvc->-r requirements.txt (line 7)) (2.19.1)
Requirement already satisfied: mdurl~=0.1 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from markdown-it-py>=2.2.0->rich>=12->dvc->-r requirements.txt (line 7)) (0.1.2)
Requirement already satisfied: ruamel.yaml.clib>=0.2.15 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from ruamel.yaml>=0.17.11->dvc->-r requirements.txt (line 7)) (0.2.15)
Requirement already satisfied: shellingham>=1.3.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from typer>=0.4.1->gto<2,>=1.6.0->dvc->-r requirements.txt (line 7)) (1.5.4)
Requirement already satisfied: setuptools in c:\users\sergio\appdata\roaming\python\python312\site-packages (from zc.lockfile>=1.2.1->dvc->-r requirements.txt (line 7)) (75.8.0)
Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc->-r requirements.txt (line 7)) (2.6.1)
Requirement already satisfied: aiosignal>=1.1.2 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc->-r requirements.txt (line 7)) (1.3.2)
Requirement already satisfied: frozenlist>=1.1.1 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc->-r requirements.txt (line 7)) (1.6.0)
Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc->-r requirements.txt (line 7)) (6.4.3)
Requirement already satisfied: propcache>=0.2.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc->-r requirements.txt (line 7)) (0.3.1)
Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc->-r requirements.txt (line 7)) (1.20.0)
Requirement already satisfied: tenacity>=6.2.0 in c:\users\sergio\appdata\roaming\python\python312\site-packages (from plotly->catboost->-r requirements.txt (line 6)) (8.5.0)

# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import  LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, KFold
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
from catboost import CatBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
#from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# # Importing Data

# %%
df = pd.read_csv(r"C:\Users\SERGIO\Desktop\Main Projects\Regression\Airbnb Price Prediction\Notebook_Experiments\Data\Airbnb_Data.csv")

# %% [markdown]
# # Data Exploration

# %%
df

# %%
df.shape

# %%
df.columns

# %%
df.describe()

# %%
df.info()

# %%
df.dtypes

# %%
df.isnull().sum()

# %%
df["zipcode"].unique

# %%
index= ["host_response_rate","property_type", "room_type","accommodates","bathrooms","bed_type", "cancellation_policy", "cleaning_fee",
       "city","instant_bookable", "beds", "bedrooms", "neighbourhood","first_review", "last_review","zipcode",
       "name","host_since","thumbnail_url", "latitude", "longitude", 
        "host_has_profile_pic", "host_identity_verified"]

for i in index:
    
    print(df[i].value_counts(), "\n")
    print("---------------------------------------------------------------")

# %% [markdown]
# # Data Pre-processing

# %% [markdown]
# # Handling Missing Values

# %%
for column in df.columns:
    
    if df[column].isnull().sum() != 0:
        
        print("========================================")
        print("\n{} :- {},  dtypes : {}".format(column,df[column].isnull().sum(),df[column].dtypes))

# %% [markdown]
# Last Review

# %%
df.last_review.fillna(method="ffill",inplace=True)

# %% [markdown]
# First Review

# %%
df.first_review.fillna(method="ffill",inplace=True)

# %% [markdown]
# Host Since

# %%
df.host_since.fillna(method="ffill",inplace=True)

# %% [markdown]
# Bathrooms

# %%
sns.distplot(df["bathrooms"])

# %%
df["bathrooms"] = df['bathrooms'].fillna(round(df["bathrooms"].median()))

# %% [markdown]
# Review_Scores_Rating

# %%
sns.distplot(df["review_scores_rating"])

# %%
df["review_scores_rating"] = df["review_scores_rating"].fillna(0)

# %% [markdown]
# Bedrooms

# %%
sns.distplot(df["bedrooms"])
plt.show()

# %%
df["bedrooms"] = df['bedrooms'].fillna((df["bathrooms"].median()))

# %% [markdown]
# Beds

# %%
sns.distplot(df["beds"])
plt.show()

# %%
df["beds"] = df["beds"].fillna((df["bathrooms"].median()))

# %% [markdown]
# Amenties

# %%
amenities_count = []
for i in df["amenities"]:
    amenities_count.append(len(i))
    
df["amenities"] = amenities_count

# %% [markdown]
# # Data Visualisation

# %%
# Function to plot catplot graphs
def plot_catplot(h,v,he,a):
    sns.set(font_scale=1.5)
    sns.catplot(x=h,kind=v,data=df,height=he, aspect = a)
    
# Function to plot catplot graphs
def plot_piechart(h):
    sns.set(font_scale=1.5)
    fig = plt.figure(figsize=(5,5))
    ax = fig.add_axes([0,0,1,1])
    ax.axis('equal')
    langs = list(df[h].unique())
    students =list(df[h].value_counts())
    ax.pie(students, labels = langs,autopct='%1.2f%%')
    plt.show()

# %%
plt.figure(figsize = (10, 8))
sns.distplot(df["log_price"])
plt.title('Price distribution')
plt.show()

# %%
plot_catplot("room_type", "count", 5, 2)

# %%
plot_piechart("room_type")

# %%
plot_catplot("city","count", 5, 2)

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
langs = list(df.city.unique())
students =list(df.city.value_counts())
ax.pie(students, labels = langs,autopct='%1.2f%%')
plt.show()

# %%
data = df.neighbourhood.value_counts()[:15]
plt.figure(figsize=(22,22))
x = list(data.index)
y = list(data.values)
x.reverse()
y.reverse()

plt.title("Most popular Neighbourhood")
plt.ylabel("Neighbourhood Area")
plt.xlabel("Number of guest who host in this area")

plt.barh(x,y)
plt.show()

# %%
plot_catplot("cancellation_policy","count",10, 2)

# %%
plot_catplot("cleaning_fee","count",6,2)

# %%
def plot_violinplot(h,v):
    plt.figure(figsize=(15,8))
    sns.set(font_scale=1.5)
    sns.violinplot(data=df, x=h, y=v, palette='GnBu_d')
    plt.title('Density and distribution of prices ', fontsize=15)
    plt.xlabel(h)
    plt.ylabel(v)

# %%
plot_violinplot("city","log_price")

# %%
plot_violinplot("room_type","log_price")

# %%
plot_violinplot("cancellation_policy","log_price")

# %%
plot_violinplot("bed_type","log_price")

# %%
plot_catplot("bed_type","count",8, 2)

# %%
categorical_col = []
numerical_col = []
for column in df.columns:
    
    if df[column].dtypes != "float64" and df[column].dtypes != "int64":
        categorical_col.append(column)
    else:
        numerical_col.append(column)

# %%
numerical_col

# %%
categorical_col

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
for col in categorical_col:
    df[col] = le.fit_transform(df[col])

# %%
pd.set_option("display.max_columns",None)
df

# %% [markdown]
# # HeatMap

# %%
plt.figure(figsize = (40,40))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap="seismic")
plt.show()

# %%
x = df.drop(["id","name","log_price","description","first_review","host_since","last_review","neighbourhood",
            "thumbnail_url", "zipcode"],axis = 1)
y = df.log_price

# %%
x

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=101)

# %% [markdown]
# ## Model Building

# %% [markdown]
# # Linear Regression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)

y_pred_lr = lr.predict(x_test)

# %%
mae_lr = metrics.mean_absolute_error(y_test, y_pred_lr)
mse_lr = metrics.mean_squared_error(y_test, y_pred_lr)
rmse_lr = np.sqrt(metrics.mean_squared_error(y_test, y_pred_lr))
r2_lr = metrics.r2_score(y_test, y_pred_lr)


print('\nMean Absolute Error of Linear Regression     : ', mae_lr)
print('\nMean Squarred Error of Linear Regression     : ', mse_lr)
print('\nRoot Mean Squarred Error of Linear Regression: ', rmse_lr)
print('\nR2 Score of Linear Regression                : ', r2_lr)

# %% [markdown]
# # Random Forest

# %%
rf = RandomForestRegressor()

# %%
rf.fit(x_train,y_train)

y_pred_rf = rf.predict(x_test)

# %%
mae_rf = metrics.mean_absolute_error(y_test, y_pred_rf)
mse_rf = metrics.mean_squared_error(y_test, y_pred_rf)
rmse_rf = np.sqrt(metrics.mean_squared_error(y_test, y_pred_rf))
r2_rf = metrics.r2_score(y_test, y_pred_rf)


print('\nMean Absolute Error of Random Forest Regressor     : ', mae_rf)
print('\nMean Squarred Error of Random Forest Regressor     : ', mse_rf)
print('\nRoot Mean Squarred Error of Random Forest Regressor: ', rmse_rf)
print('\nR2 Score of Random Forest Regressor                : ', r2_rf)

# %% [markdown]
# # Polynomial Regression

# %%
from sklearn.linear_model import Ridge
model = Pipeline([
    ('poly', PolynomialFeatures()),
    ('ridge', Ridge(fit_intercept=True))
])

param_grid = {
    'poly__degree': [1, 2, 3],
    'ridge__alpha': [0.1, 0.5, 1.0, 2.0]
}

# Perform grid search with 5-fold cross-validation

poly_tuned = GridSearchCV(model, param_grid, cv=5)

# %%
#Traning and Testing

poly_tuned.fit(x_train, y_train)

y_pred_poly = poly_tuned.predict(x_test)

# %%
mae_poly  = metrics.mean_absolute_error(y_test, y_pred_poly)
mse_poly  = metrics.mean_squared_error(y_test, y_pred_poly)
rmse_poly = np.sqrt(metrics.mean_squared_error(y_test, y_pred_poly))
r2_poly   = metrics.r2_score(y_test, y_pred_poly)


print('\nMean Absolute Error of Polynomial Regression     : ', mae_poly)
print('\nMean Squarred Error of Polynomial Regression     : ', mse_poly)
print('\nRoot Mean Squarred Error of Polynomial Regression: ', rmse_poly)
print('\nR2 Score of Polynomial Regression                : ', r2_poly)

# %% [markdown]
# # CatBoost

# %%
model_CBR = CatBoostRegressor()

# %%
model_CBR.fit(x_train, y_train)

cross_val_score(model_CBR, x_train, y_train,
                           scoring='r2',
                           cv=KFold(n_splits=5,
                                    shuffle=True,
                                    random_state=2022,
                                    ))

# %%
y_pred_cbr = model_CBR.predict(x_test)

# %%
mae_cbr  = metrics.mean_absolute_error(y_test, y_pred_cbr)
mse_cbr  = metrics.mean_squared_error(y_test, y_pred_cbr)
rmse_cbr = np.sqrt(metrics.mean_squared_error(y_test, y_pred_cbr))
r2_cbr   = metrics.r2_score(y_test, y_pred_cbr)


print('\nMean Absolute Error of CatBoost Regressor     : ', mae_cbr)
print('\nMean Squarred Error of CatBoost Regressor     : ', mse_cbr)
print('\nRoot Mean Squarred Error of CatBoost Regressor: ', rmse_cbr)
print('\nR2 Score of CatBoost Regressor                : ', r2_cbr)

# %% [markdown]
# # Gradient Boosting

# %%
gb = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3)

# %%
gb.fit(x_train, y_train)

y_pred_gb = gb.predict(x_test)

# %%
mae_gb  = metrics.mean_absolute_error(y_test, y_pred_gb)
mse_gb  = metrics.mean_squared_error(y_test, y_pred_gb)
rmse_gb = np.sqrt(metrics.mean_squared_error(y_test, y_pred_gb))
r2_gb   = metrics.r2_score(y_test, y_pred_gb)


print('\nMean Absolute Error of Gradient Boosting     : ', mae_gb)
print('\nMean Squarred Error of Gradient Boosting     : ', mse_gb)
print('\nRoot Mean Squarred Error of Gradient Boosting: ', rmse_gb)
print('\nR2 Score of Gradient Boosting                : ', r2_gb)

# %% [markdown]
# # XGBoost

# %%
xgb = XGBRegressor(objective='reg:squarederror')

# %%
xgb.fit(x_train, y_train)

# %%
y_pred_xgb = xgb.predict(x_test)

# %%
mae_xgb  = metrics.mean_absolute_error(y_test, y_pred_xgb)
mse_xgb  = metrics.mean_squared_error(y_test, y_pred_xgb)
rmse_xgb = np.sqrt(metrics.mean_squared_error(y_test, y_pred_xgb))
r2_xgb   = metrics.r2_score(y_test, y_pred_xgb)


print('\nMean Absolute Error of XGBoost Regressor     : ', mae_xgb)
print('\nMean Squarred Error of XGBoost Regressor     : ', mse_xgb)
print('\nRoot Mean Squarred Error of XGBoost Regressor: ', rmse_xgb)
print('\nR2 Score of XGBoost Regressor                : ', r2_xgb)

# %%
r2_list = {"Linear Regression": r2_lr,
          "Random Forest": r2_rf ,
          "Polynomial Regression": r2_poly,
          "CatBoost": r2_cbr,
          "Gradient Boosting":r2_gb ,
          "XGBoost": r2_xgb}

mae_list = {"Linear Regression": mae_lr,
          "Random Forest": mae_rf ,
          "Polynomial Regression": mae_poly,
          "CatBoost": mae_cbr,
          "Gradient Boosting":mae_gb ,
          "XGBoost": mae_xgb}

mse_list = {"Linear Regression": mse_lr,
          "Random Forest": mse_rf ,
          "Polynomial Regression": mse_poly,
          "CatBoost": mse_cbr,
          "Gradient Boosting":mse_gb ,
          "XGBoost": mse_xgb}

rmse_list = {"Linear Regression": rmse_lr,
          "Random Forest": rmse_rf ,
          "Polynomial Regression": rmse_poly,
          "CatBoost": rmse_cbr,
          "Gradient Boosting":rmse_gb ,
          "XGBoost": rmse_xgb}

# %%
a1 =  pd.DataFrame.from_dict(r2_list, orient = 'index', columns = ["R2 SCORE"])
a2 =  pd.DataFrame.from_dict(mae_list, orient = 'index', columns = ["MEAN ABSOLUTE ERROR"])
a3 =  pd.DataFrame.from_dict(mse_list, orient = 'index', columns = ["MEAN SQUARRED ERROR"])
a4 =  pd.DataFrame.from_dict(rmse_list, orient = 'index', columns = ["ROOT MEAN SQUARRED ERROR"])

# %%
org = pd.concat([a1, a2, a3, a4], axis = 1)
org

# %%
alg = ['LR','RF','PR','CBR','GB','XGB']
plt.plot(alg,a1)
plt.plot(alg,a2)
plt.plot(alg,a3)
plt.plot(alg,a4)
legend = ["R2 SCORE", "MEAN ABSOLUTE ERROR", "MEAN SQUARRED ERROR", "ROOT MEAN SQUARRED ERROR"]

plt.title("METRICS COMPARISION")
plt.legend(legend, loc= 'right', fontsize='xx-small')
plt.show()

# %%
import pickle
pickle.dump(model_CBR, open("catboostalgo.pkl", "wb"))

# %% [markdown]
# # Model Monitoring

# %%
try:
    import evidently
except:
    # !pip install git+https://github.com/evidentlyai/evidently.git

# %%
import pandas as pd
import numpy as np
import requests
import io

from evidently import ColumnMapping
from evidently.report import Report
from evidently.metric_preset import DataDriftPreset, TargetDriftPreset, RegressionPreset

# %%
target = 'log_price'
prediction = 'prediction'
numerical_features = numerical_col
categorical_features = categorical_col

# %%
reference = df.loc[:25000]

current = df.loc[25000:]

# %%
regressor = model_CBR

# %%
regressor.fit(reference[numerical_features+categorical_features],reference[target])

# %%
ref_prediction = regressor.predict(reference[numerical_features+categorical_features])

current_prediction = regressor.predict(current[numerical_features+categorical_features])

# %%
reference['prediction'] = ref_prediction

current['prediction'] = current_prediction

# %%
column_mapping = ColumnMapping()

column_mapping.target = target
column_mapping.prediction = prediction
column_mapping.numerical_features = numerical_features
column_mapping.categorical_features = categorical_features

# %%
regression_perfomance = Report(metrics=[RegressionPreset()])
regression_perfomance.run(current_data=reference, reference_data=None, column_mapping=column_mapping)

# %%
regression_perfomance.show()
